# %%
#Carrie Gold
#BMI 6018
#Module 2
#Quiz
#9/7/23

#Provide a link with code for the following questions:  
#Question 1 (Booleans),  
#Question 2 (Booleans 2),  
#Question 5 (Strings), 
#Question 6 (Strings 2),  
#Question 9 (Operators 2), and 
#Question 10 (String 3)
#Response for each question is 5 points.
#Include comments to indicate each question title and question such as
# Booleans
 # boolean True + boolean True - boolean False = ?  
#Your code....


#Question 1: Booleans
#boolean True + boolean True - boolean False = ? 

answer_1 = True + True - False
print("1. ", answer_1)


#Question 2: Booleans 2
#logical tracker = True
#logical tracker = logical tracker & logical tracker
#logical tracker = logical tracker | (logical tracker - logical tracker)
#logical tracker  = ?

var_1 = True 
var_1 = var_1 and var_1
var_1 = var_1 or (var_1 - var_1)
print("2. ",var_1)


#Question 5: Strings
#string = "E. Coli"
#string[2]=

ex_str = "E. Coli"
print("5. ","'", ex_str[2],"'")


#Question 6: Strings 2
#Oh no! My string has a typo!
#string = "I Bove python"
#No worries though. I'll just fix that.
#string[2]="L"

#Note, this code cannot edit the string because
#Python strings are immutable. However, variable  
#labeling the string can be re-defined, and then the 
#latest definition will be what is called when the 
#variable is called.

str_1 = "I bove Python"
str_1 = "I love Python"
print("6. ",str_1)


#Question 9: Operators 2
#Explain how the "+", addition operation works 
#differently for integers and strings.

var_2 = 5 + 5
print("9. Integers: ", var_2)

str_2 = "I love "
str_3 = "Python"
var_3 = str_2 + str_3 
print("Strings: ",var_3)


#Question 10: Strings 3
#Type the output if the strings "7" and "3" are added

str_4 = "7"
str_5 = "3"
print("10. ",str_4 + str_5)
# Out:
# 1.  2
# 2.  True
# 5.  '   '
# 6.  I love Python
# 9. Integers:  10
# Strings:  I love Python
# 10.  73
